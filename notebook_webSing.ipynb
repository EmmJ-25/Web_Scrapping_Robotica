# %%
from urllib.request import urlopen, Request
request = Request('https://google.com')
with urlopen(request) as response:
received_bytes = response.read('utf-8')
content = received_bytes.decode()
print(content[:72])

# %%
data = urlencode({'key': 'value'}).encode()
request = Request('https://httpbin.org/anything'
, data=data)
with urlopen(request) as response:
print(response.read().decode())

# %% [markdown]
# lo de arriba es hacer un post
# Hay que indicar como queremos mandarlo, poque por defecto envia en POST
# Formularios y POST

# %%
//Formularios y POST
